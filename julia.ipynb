# %%
!wget https://developer.nvidia.com/compute/...
!dpkg -i cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
!apt-key add /var/cuda-repo-9-0-local/7fa2af80.pub
!apt update -q
!apt install cuda gcc-6 g++-6 -y -q
!ln -s /usr/bin/gcc-6 /usr/local/cuda/bin/gcc
!ln -s /usr/bin/g++-6 /usr/local/cuda/bin/g++

# %%
!curl -sSL "https://julialang-s3.julialang.org/bin/linux/x64/1.2/julia-1.2.0-linux-x86_64.tar.gz" -o julia.tar.gz
!tar -xzf julia.tar.gz -C /usr --strip-components 1
!rm -rf julia.tar.gz*
!julia -e 'using Pkg; pkg"add IJulia; precompile"'
!echo "DONE"

# %%
using DataFrames
using CSV

# %%
df = DataFrame!(CSV.File("netflix_titles.csv"));

# %%
head(df)
# Out:
# ┌ Warning: `head(df::AbstractDataFrame)` is deprecated, use `first(df, 6)` instead.
# │   caller = top-level scope at In[14]:1
# └ @ Core In[14]:1
# 6×12 DataFrame. Omitted printing of 9 columns
# │ Row │ show_id  │ type    │ title                                   │
# │     │ Int64    │ String  │ String                                  │
# ├─────┼──────────┼─────────┼─────────────────────────────────────────┤
# │ 1   │ 81145628 │ Movie   │ Norm of the North: King Sized Adventure │
# │ 2   │ 80117401 │ Movie   │ Jandino: Whatever it Takes              │
# │ 3   │ 70234439 │ TV Show │ Transformers Prime                      │
# │ 4   │ 80058654 │ TV Show │ Transformers: Robots in Disguise        │
# │ 5   │ 80125979 │ Movie   │ #realityhigh                            │
# │ 6   │ 80163890 │ TV Show │ Apaches                                 │

# %%
tail(df)
# Out:
# ┌ Warning: `tail(df::AbstractDataFrame)` is deprecated, use `last(df, 6)` instead.
# │   caller = top-level scope at In[15]:1
# └ @ Core In[15]:1
# 6×12 DataFrame. Omitted printing of 9 columns
# │ Row │ show_id  │ type    │ title                                       │
# │     │ Int64    │ String  │ String                                      │
# ├─────┼──────────┼─────────┼─────────────────────────────────────────────┤
# │ 1   │ 80159925 │ TV Show │ Kikoriki                                    │
# │ 2   │ 80000063 │ TV Show │ Red vs. Blue                                │
# │ 3   │ 70286564 │ TV Show │ Maron                                       │
# │ 4   │ 80116008 │ Movie   │ Little Baby Bum: Nursery Rhyme Friends      │
# │ 5   │ 70281022 │ TV Show │ A Young Doctor's Notebook and Other Stories │
# │ 6   │ 70153404 │ TV Show │ Friends                                     │

# %%
eltypes(df)
# Out:
# ┌ Warning: `eltypes(df::AbstractDataFrame)` is deprecated, use `eltype.(eachcol(df))` instead.
# │   caller = top-level scope at In[20]:1
# └ @ Core In[20]:1
# 12-element Array{Type,1}:
#  Int64
#  String
#  String
#  Union{Missing, String}
#  Union{Missing, String}
#  Union{Missing, String}
#  Union{Missing, String}
#  Int64
#  Union{Missing, String}
#  String
#  String
#  String

# %%
names(df)
# Out:
# 12-element Array{String,1}:
#  "show_id"
#  "type"
#  "title"
#  "director"
#  "cast"
#  "country"
#  "date_added"
#  "release_year"
#  "rating"
#  "duration"
#  "listed_in"
#  "description"

# %%
using Plots

# %%
scatter(df.rating, title = "Distribution of Ratings", label = "")

# %%
histogram(df.release_year, title = "Distribution of Release Years", label = "")
